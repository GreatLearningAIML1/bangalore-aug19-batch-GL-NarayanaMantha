# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
#using read_csv to read the csv file into a data frame Iris
Iris = pd.read_csv('Iris.csv')
#This prints the 1st 5 entries from the dataframe.
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
#This info gives the column names, number of non-null entries in each column and the data type of entries in each column
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#printing top 10 samples from the dataframe using head function
Iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
#printing last 10 samples from the dataframe using tail function
Iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
#printing the shape of the dataset (# Rows, #Columns)
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.set_index("Sepal Length (in cm)", inplace=False)
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# 4.3                                   3.0                   1.1
# 5.8                                   4.0                   1.2
# 5.7                                   4.4                   1.5
# 5.4                                   3.9                   1.3
# 5.1                                   3.5                   1.4
# 5.7                                   3.8                   1.7
# 5.1                                   3.8                   1.5
# 5.4                                   3.4                   1.7
# 5.1                                   3.7                   1.5
# 4.6                                   3.6                   1.0
# 5.1                                   3.3                   1.7
# 4.8                                   3.4                   1.9
# 5.0                                   3.0                   1.6
# 5.0                                   3.4                   1.6
# 5.2                                   3.5                   1.5
# 5.2                                   3.4                   1.4
# 4.7                                   3.2                   1.6
# ...                                   ...                   ...
# 6.9                                   3.2                   5.7
# 5.6                                   2.8                   4.9
# 7.7                                   2.8                   6.7
# 6.3                                   2.7                   4.9
# 6.7                                   3.3                   5.7
# 7.2                                   3.2                   6.0
# 6.2                                   2.8                   4.8
# 6.1                                   3.0                   4.9
# 6.4                                   2.8                   5.6
# 7.2                                   3.0                   5.8
# 7.4                                   2.8                   6.1
# 7.9                                   3.8                   6.4
# 6.4                                   2.8                   5.6
# 6.3                                   2.8                   5.1
# 6.1                                   2.6                   5.6
# 7.7                                   3.0                   6.1
# 6.3                                   3.4                   5.6
# 6.4                                   3.1                   5.5
# 6.0                                   3.0                   4.8
# 6.9                                   3.1                   5.4
# 6.7                                   3.1                   5.6
# 6.9                                   3.1                   5.1
# 5.8                                   2.7                   5.1
# 6.8                                   3.2                   5.9
# 6.7                                   3.3                   5.7
# 6.7                                   3.0                   5.2
# 6.3                                   2.5                   5.0
# 6.5                                   3.0                   5.2
# 6.2                                   3.4                   5.4
# 5.9                                   3.0                   5.1
#
#                       Petal width (in cm)           Class
# Sepal Length (in cm)
# 5.1                                   0.2     Iris-setosa
# 4.9                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 4.6                                   0.3     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 4.4                                   0.2     Iris-setosa
# 4.9                                   0.1     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 4.8                                   0.1     Iris-setosa
# 4.3                                   0.1     Iris-setosa
# 5.8                                   0.2     Iris-setosa
# 5.7                                   0.4     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.7                                   0.3     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 5.1                                   0.4     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.1                                   0.5     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.0                                   0.4     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# ...                                   ...             ...
# 6.9                                   2.3  Iris-virginica
# 5.6                                   2.0  Iris-virginica
# 7.7                                   2.0  Iris-virginica
# 6.3                                   1.8  Iris-virginica
# 6.7                                   2.1  Iris-virginica
# 7.2                                   1.8  Iris-virginica
# 6.2                                   1.8  Iris-virginica
# 6.1                                   1.8  Iris-virginica
# 6.4                                   2.1  Iris-virginica
# 7.2                                   1.6  Iris-virginica
# 7.4                                   1.9  Iris-virginica
# 7.9                                   2.0  Iris-virginica
# 6.4                                   2.2  Iris-virginica
# 6.3                                   1.5  Iris-virginica
# 6.1                                   1.4  Iris-virginica
# 7.7                                   2.3  Iris-virginica
# 6.3                                   2.4  Iris-virginica
# 6.4                                   1.8  Iris-virginica
# 6.0                                   1.8  Iris-virginica
# 6.9                                   2.1  Iris-virginica
# 6.7                                   2.4  Iris-virginica
# 6.9                                   2.3  Iris-virginica
# 5.8                                   1.9  Iris-virginica
# 6.8                                   2.3  Iris-virginica
# 6.7                                   2.5  Iris-virginica
# 6.7                                   2.3  Iris-virginica
# 6.3                                   1.9  Iris-virginica
# 6.5                                   2.0  Iris-virginica
# 6.2                                   2.3  Iris-virginica
# 5.9                                   1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
#Using slicing technique for this. ':' tells us to print all the rows in the column 2. Since this is an iloc function, we can use the column index instead of column name
Iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
#Using silicing technique, telling the # of rows is 0-9 and printing columns 2 and 3.
Iris.iloc[0:10,1:3]
# Out:
#    Sepal Width in (cm)  Petal length (in cm)
# 0                  3.5                   1.4
# 1                  3.0                   1.4
# 2                  3.2                   1.3
# 3                  3.1                   1.5
# 4                  3.6                   1.4
# 5                  3.9                   1.7
# 6                  3.4                   1.4
# 7                  3.4                   1.5
# 8                  2.9                   1.4
# 9                  3.1                   1.5

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
#First checking if Iris["Class"] is equal to the given class name and using that output as index to print the data frame.
Iris[Iris["Class"] == "Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
#Creating a new column SepalExtra (in cm2) in the current dataframe. 
#Multiplying Sepal Length and Sepal Width in the above new column
Iris["SepalExtra (in cm2)"] = Iris["Sepal Length (in cm)"] * Iris["Sepal Width in (cm)"]

# %%
#Now printing the new column
Iris.iloc[:,-1]
# Out:
# 0      17.85
# 1      14.70
# 2      15.04
# 3      14.26
# 4      18.00
# 5      21.06
# 6      15.64
# 7      17.00
# 8      12.76
# 9      15.19
# 10     19.98
# 11     16.32
# 12     14.40
# 13     12.90
# 14     23.20
# 15     25.08
# 16     21.06
# 17     17.85
# 18     21.66
# 19     19.38
# 20     18.36
# 21     18.87
# 22     16.56
# 23     16.83
# 24     16.32
# 25     15.00
# 26     17.00
# 27     18.20
# 28     17.68
# 29     15.04
#        ...
# 120    22.08
# 121    15.68
# 122    21.56
# 123    17.01
# 124    22.11
# 125    23.04
# 126    17.36
# 127    18.30
# 128    17.92
# 129    21.60
# 130    20.72
# 131    30.02
# 132    17.92
# 133    17.64
# 134    15.86
# 135    23.10
# 136    21.42
# 137    19.84
# 138    18.00
# 139    21.39
# 140    20.77
# 141    21.39
# 142    15.66
# 143    21.76
# 144    22.11
# 145    20.10
# 146    15.75
# 147    19.50
# 148    21.08
# 149    17.70
# Name: SepalExtra (in cm2), Length: 150, dtype: float64

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
#printing the mean value of all numerical columns
Iris.mean(numeric_only=True)
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra (in cm2)     17.806533
# dtype: float64

# %%
#printing the variance value of all numerical columns
Iris.var(numeric_only=True)
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra (in cm2)     11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
#defining the function print_2 which takes 2 inputs and prints them.
def print_2(n1, n2):
    print("Input1 = ", n1)
    print("Input2 = ", n2)

#calling print_2() with Sepal length and sepal width of 5th row
#Using iloc and item functions to find the single index value
print_2(Iris.iloc[4,0], Iris.iloc[4,1])
#Using at() method find the single index value
#print_2(Iris.at[4, "Sepal Length (in cm)"], Iris.at[4, "Sepal Width in (cm)"])
# Out:
# Input1 =  5.0
# Input2 =  3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
#using max() and min() functions with numeric_only=True to find range. 
Iris.max(numeric_only=True) - Iris.min(numeric_only=True)
# Out:
# Sepal Length (in cm)     3.60
# Sepal Width in (cm)      2.40
# Petal length (in cm)     5.90
# Petal width (in cm)      2.40
# SepalExtra (in cm2)     20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
# using sort_values method to sort by the required column
Iris.sort_values(by=["Petal width (in cm)"])
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 0                     5.1                  3.5                   1.4
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# 30                    4.8                  3.1                   1.6
# 33                    5.5                  4.2                   1.4
# 36                    5.5                  3.5                   1.3
# 38                    4.4                  3.0                   1.3
# 39                    5.1                  3.4                   1.5
# 42                    4.4                  3.2                   1.3
# 46                    5.1                  3.8                   1.6
# 47                    4.6                  3.2                   1.4
# 48                    5.3                  3.7                   1.5
# 49                    5.0                  3.3                   1.4
# 25                    5.0                  3.0                   1.6
# 24                    4.8                  3.4                   1.9
# 35                    5.0                  3.2                   1.2
# 3                     4.6                  3.1                   1.5
# 2                     4.7                  3.2                   1.3
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 10                    5.4                  3.7                   1.5
# 4                     5.0                  3.6                   1.4
# 11                    4.8                  3.4                   1.6
# ..                    ...                  ...                   ...
# 111                   6.4                  2.7                   5.3
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 147                   6.5                  3.0                   5.2
# 113                   5.7                  2.5                   5.0
# 131                   7.9                  3.8                   6.4
# 110                   6.5                  3.2                   5.1
# 139                   6.9                  3.1                   5.4
# 102                   7.1                  3.0                   5.9
# 112                   6.8                  3.0                   5.5
# 105                   7.6                  3.0                   6.6
# 124                   6.7                  3.3                   5.7
# 128                   6.4                  2.8                   5.6
# 117                   7.7                  3.8                   6.7
# 132                   6.4                  2.8                   5.6
# 104                   6.5                  3.0                   5.8
# 120                   6.9                  3.2                   5.7
# 115                   6.4                  3.2                   5.3
# 148                   6.2                  3.4                   5.4
# 141                   6.9                  3.1                   5.1
# 143                   6.8                  3.2                   5.9
# 145                   6.7                  3.0                   5.2
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 140                   6.7                  3.1                   5.6
# 114                   5.8                  2.8                   5.1
# 100                   6.3                  3.3                   6.0
# 144                   6.7                  3.3                   5.7
# 109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class  SepalExtra (in cm2)
# 32                   0.1     Iris-setosa                21.32
# 13                   0.1     Iris-setosa                12.90
# 37                   0.1     Iris-setosa                15.19
# 9                    0.1     Iris-setosa                15.19
# 12                   0.1     Iris-setosa                14.40
# 34                   0.1     Iris-setosa                15.19
# 0                    0.2     Iris-setosa                17.85
# 27                   0.2     Iris-setosa                18.20
# 28                   0.2     Iris-setosa                17.68
# 29                   0.2     Iris-setosa                15.04
# 30                   0.2     Iris-setosa                14.88
# 33                   0.2     Iris-setosa                23.10
# 36                   0.2     Iris-setosa                19.25
# 38                   0.2     Iris-setosa                13.20
# 39                   0.2     Iris-setosa                17.34
# 42                   0.2     Iris-setosa                14.08
# 46                   0.2     Iris-setosa                19.38
# 47                   0.2     Iris-setosa                14.72
# 48                   0.2     Iris-setosa                19.61
# 49                   0.2     Iris-setosa                16.50
# 25                   0.2     Iris-setosa                15.00
# 24                   0.2     Iris-setosa                16.32
# 35                   0.2     Iris-setosa                16.00
# 3                    0.2     Iris-setosa                14.26
# 2                    0.2     Iris-setosa                15.04
# 7                    0.2     Iris-setosa                17.00
# 8                    0.2     Iris-setosa                12.76
# 10                   0.2     Iris-setosa                19.98
# 4                    0.2     Iris-setosa                18.00
# 11                   0.2     Iris-setosa                16.32
# ..                   ...             ...                  ...
# 111                  1.9  Iris-virginica                17.28
# 121                  2.0  Iris-virginica                15.68
# 122                  2.0  Iris-virginica                21.56
# 147                  2.0  Iris-virginica                19.50
# 113                  2.0  Iris-virginica                14.25
# 131                  2.0  Iris-virginica                30.02
# 110                  2.0  Iris-virginica                20.80
# 139                  2.1  Iris-virginica                21.39
# 102                  2.1  Iris-virginica                21.30
# 112                  2.1  Iris-virginica                20.40
# 105                  2.1  Iris-virginica                22.80
# 124                  2.1  Iris-virginica                22.11
# 128                  2.1  Iris-virginica                17.92
# 117                  2.2  Iris-virginica                29.26
# 132                  2.2  Iris-virginica                17.92
# 104                  2.2  Iris-virginica                19.50
# 120                  2.3  Iris-virginica                22.08
# 115                  2.3  Iris-virginica                20.48
# 148                  2.3  Iris-virginica                21.08
# 141                  2.3  Iris-virginica                21.39
# 143                  2.3  Iris-virginica                21.76
# 145                  2.3  Iris-virginica                20.10
# 118                  2.3  Iris-virginica                20.02
# 135                  2.3  Iris-virginica                23.10
# 136                  2.4  Iris-virginica                21.42
# 140                  2.4  Iris-virginica                20.77
# 114                  2.4  Iris-virginica                16.24
# 100                  2.5  Iris-virginica                20.79
# 144                  2.5  Iris-virginica                22.11
# 109                  2.5  Iris-virginica                25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
#dropping the column in original dataframe as well
Iris.drop(columns="SepalExtra (in cm2)",inplace=True)

# %%
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
#using iloc method to do this.
IrisSubset = Iris.iloc[0:10,0:3]
print(IrisSubset)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
#reading the txt file using read_csv and making sure the separator/delimiter is correct
Hr_df = pd.read_csv("HR_external.txt",sep='\t')

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
#printing the # of rows and columns using shape method
Hr_df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
#using info method to print the type of all columns
Hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Individual                  1470 non-null object
# Attrition                   1470 non-null object
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null int64
# DailyRate                   1470 non-null int64
# Department                  1470 non-null int64
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null int64
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null int64
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null int64
# JobSatisfaction             1470 non-null int64
# MaritalStatus               1470 non-null int64
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# OverTime                    1470 non-null int64
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# StandardHours               1470 non-null int64
# StockOptionLevel            1470 non-null int64
# TotalWorkingYears           1470 non-null int64
# TrainingTimesLastYear       1470 non-null int64
# WorkLifeBalance             1470 non-null int64
# YearsAtCompany              1470 non-null int64
# YearsInCurrentRole          1470 non-null int64
# YearsSinceLastPromotion     1470 non-null int64
# YearsWithCurrManager        1470 non-null int64
# dtypes: int64(33), object(2)
# memory usage: 402.0+ KB

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
#extracting all rows from 3rd column to 10th column
Hr_df.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# 5                  1              1
# 6                  2              1
# 7                  1              1
# 8                  1              1
# 9                  2              1
# 10                 2              1
# 11                 1              1
# 12                 1              1
# 13                 2              1
# 14                 1              1
# 15                 1              1
# 16                 1              1
# 17                 2              1
# 18                 1              1
# 19                 1              1
# 20                 6              1
# 21                 1              1
# 22                 1              1
# 23                 1              1
# 24                 2              1
# 25                 6              1
# 26                 1              1
# 27                 3              1
# 28                 2              1
# 29                 3              1
# ...              ...            ...
# 1440               1              1
# 1441               1              1
# 1442               2              1
# 1443               1              1
# 1444               4              1
# 1445               1              1
# 1446               3              1
# 1447               3              1
# 1448               1              1
# 1449               4              1
# 1450               1              1
# 1451               1              1
# 1452               1              1
# 1453               3              1
# 1454               1              1
# 1455               1              1
# 1456               1              1
# 1457               2              1
# 1458               1              1
# 1459               6              1
# 1460               2              1
# 1461               3              1
# 1462               3              1
# 1463               2              1
# 1464               6              1
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
#Assuming Gender = 1 is male and Gender = 2 is female
#The below line finds the number of male employees using sum() method
print("Number of male employees = ", (Hr_df["Gender"] == 1).sum())
# Out:
# Number of male employees =  882

# %%
print("Number of female employees = ", (Hr_df["Gender"] == 2).sum())
# Out:
# Number of female employees =  588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
#IQR = 75th percentile - 25th percentile
#using the quantile method on Age column
print("IQR = ", Hr_df["Age"].quantile(q=0.75) - Hr_df["Age"].quantile(q=0.25))
# Out:
# IQR =  13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
#using the mean()
print("Mean for the column - DailyRate is ", Hr_df["DailyRate"].mean())
# Out:
# Mean for the column - DailyRate is  802.4857142857143

# %%
#using the median()
print("Median for the column - DailyRate is ", Hr_df["DailyRate"].median())
# Out:
# Median for the column - DailyRate is  802.0

# %%
#using the variance()
print("Variance for the column - DailyRate is ", Hr_df["DailyRate"].var())
# Out:
# Variance for the column - DailyRate is  162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

#The below plot is for categorical streams
sns.countplot(Hr_df["Attrition"])

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
#Using matplotlib plot and show functions to plot this.
#plt.plot(Hr_df["TotalWorkingYears"])
#plt.show()
Hr_df["TotalWorkingYears"].plot(kind='hist')
